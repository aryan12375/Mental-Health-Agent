# %% [markdown]
# <a href="https://colab.research.google.com/github/aryan12375/Mental-Health-Agent/blob/main/Mental_Health_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Clone the project
# !git clone https://github.com/aryan12375/Mental-Health-Agent.git
# %cd Mental-Health-Agent

# 2. Install dependencies
# !pip install -r requirements.txt

print("\n✅ Environment Ready!")
# Out:
# Cloning into 'Mental-Health-Agent'...
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 20 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (20/20), 69.37 KiB | 8.67 MiB/s, done.
# Resolving deltas: 100% (2/2), done.
# /content/Mental-Health-Agent
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 2.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.3/107.3 kB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.5/103.5 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 77.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.1/779.1 MB 804.7 kB/s eta 0:00:00
# ...

# %%
import os
from getpass import getpass

# Paste your GROQ_API_KEY here (or whichever key you used in your code)
os.environ["GROQ_API_KEY"] = getpass("Paste your Groq API Key here: ")

# %%
# Run the main agent logic
# !python main.py
